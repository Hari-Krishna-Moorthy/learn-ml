# %%
import pandas as pd

# %% [markdown]
# # 1. Createing a dataframe

# %%
df = pd.DataFrame(columns=["age", "name", "id"])
df["age"] = [32, 26, 20, 24, 19, 31]
df["name"] = ["ram", "sita", "sab", "raj", "priya", "Tom"]
df["id"] = [2, 5, 8, 1, 25, 3]
df["job"] = ['01-01-1988', '02-11-1994', '04-10-2000', 
             '31-13-1996', '02-06-2001', '07-03-1989']

df
# Out:
#    age   name  id         job
# 0   32    ram   2  01-01-1988
# 1   26   sita   5  02-11-1994
# 2   20    sab   8  04-10-2000
# 3   24    raj   1  31-13-1996
# 4   19  priya  25  02-06-2001
# 5   31    Tom   3  07-03-1989

# %% [markdown]
# # 2. head - tails

# %%
display("top rows", df.head(), "bottom rows", df.tail())
# Out:
# 'top rows'
#    age   name  id         job
# 0   32    ram   2  01-01-1988
# 1   26   sita   5  02-11-1994
# 2   20    sab   8  04-10-2000
# 3   24    raj   1  31-13-1996
# 4   19  priya  25  02-06-2001
# 'bottom rows'
#    age   name  id         job
# 1   26   sita   5  02-11-1994
# 2   20    sab   8  04-10-2000
# 3   24    raj   1  31-13-1996
# 4   19  priya  25  02-06-2001
# 5   31    Tom   3  07-03-1989

# %% [markdown]
# # 3. Selecting a contiguous portion of df

# %%
print("showing 2 columns and 3 rows stating from the 2nd column 2nd row")

df_new = df.iloc[1:4, 1:3]
df_new
# Out:
# showing 2 columns and 3 rows stating from the 2nd column 2nd row
#    name  id
# 1  sita   5
# 2   sab   8
# 3   raj   1

# %% [markdown]
# # 4. Selecting some columns

# %%
print("showing id and age")
df_new = df[["id", "age"]]
df_new
# Out:
# showing id and age
#    id  age
# 0   2   32
# 1   5   26
# 2   8   20
# 3   1   24
# 4  25   19
# 5   3   31

# %% [markdown]
# # 5. Renaming columns

# %%
df.rename({"id": "col 1", "name" : "col 2"}, 
                  axis="columns",
                   inplace=True) # one by one

display(df)
df.columns = ["age", "name", "id", "dob"] 
display(df)
# Out:
#    age  col 2  col 1         job
# 0   32    ram      2  01-01-1988
# 1   26   sita      5  02-11-1994
# 2   20    sab      8  04-10-2000
# 3   24    raj      1  31-13-1996
# 4   19  priya     25  02-06-2001
# 5   31    Tom      3  07-03-1989
#    age   name  id         dob
# 0   32    ram   2  01-01-1988
# 1   26   sita   5  02-11-1994
# 2   20    sab   8  04-10-2000
# 3   24    raj   1  31-13-1996
# 4   19  priya  25  02-06-2001
# 5   31    Tom   3  07-03-1989

# %% [markdown]
# # 6. splitting a string column

# %%
df[["day", "month", "year"]] = df["dob"].str.split("-", expand=True)
df
# Out:
#    age   name  id         dob day month  year
# 0   32    ram   2  01-01-1988  01    01  1988
# 1   26   sita   5  02-11-1994  02    11  1994
# 2   20    sab   8  04-10-2000  04    10  2000
# 3   24    raj   1  31-13-1996  31    13  1996
# 4   19  priya  25  02-06-2001  02    06  2001
# 5   31    Tom   3  07-03-1989  07    03  1989

# %% [markdown]
# # 7. Concatenation string columns

# %%
df["mod_date"] = df["month"] + "-" + df["day"] + "-" + df["year"]
df
# Out:
#    age   name  id         dob day month  year    mod_date
# 0   32    ram   2  01-01-1988  01    01  1988  01-01-1988
# 1   26   sita   5  02-11-1994  02    11  1994  11-02-1994
# 2   20    sab   8  04-10-2000  04    10  2000  10-04-2000
# 3   24    raj   1  31-13-1996  31    13  1996  13-31-1996
# 4   19  priya  25  02-06-2001  02    06  2001  06-02-2001
# 5   31    Tom   3  07-03-1989  07    03  1989  03-07-1989

# %% [markdown]
# # 8. Filtering with multiple criteria

# %%
df_new = df[
    (df["age"] < 25) &
    (df["id"] >= 3)
]

df_new
# Out:
#    age   name  id         dob day month  year    mod_date
# 2   20    sab   8  04-10-2000  04    10  2000  10-04-2000
# 4   19  priya  25  02-06-2001  02    06  2001  06-02-2001

# %% [markdown]
# # 9. One hot encoding

# %%
df_new = pd.get_dummies(df, prefix="mo", 
                        prefix_sep="_", 
                        columns=["month"],
                        drop_first=True
                       )
df_new
# Out:
#    age   name  id         dob day  year    mod_date  mo_03  mo_06  mo_10
# 0   32    ram   2  01-01-1988  01  1988  01-01-1988  False  False  False  \
# 1   26   sita   5  02-11-1994  02  1994  11-02-1994  False  False  False
# 2   20    sab   8  04-10-2000  04  2000  10-04-2000  False  False   True
# 3   24    raj   1  31-13-1996  31  1996  13-31-1996  False  False  False
# 4   19  priya  25  02-06-2001  02  2001  06-02-2001  False   True  False
# 5   31    Tom   3  07-03-1989  07  1989  03-07-1989   True  False  False
#
#    mo_11  mo_13
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False   True
# 4  False  False
# 5  False  False

# %% [markdown]
# # 10. Continuous variable to categorical

# %%
df["cat_age"] = pd.cut(df["age"].values, 
                      bins=[0,30,60],
                      labels=["20's", "30's"])

df
# Out:
#    age   name  id         dob day month  year    mod_date cat_age
# 0   32    ram   2  01-01-1988  01    01  1988  01-01-1988    30's
# 1   26   sita   5  02-11-1994  02    11  1994  11-02-1994    20's
# 2   20    sab   8  04-10-2000  04    10  2000  10-04-2000    20's
# 3   24    raj   1  31-13-1996  31    13  1996  13-31-1996    20's
# 4   19  priya  25  02-06-2001  02    06  2001  06-02-2001    20's
# 5   31    Tom   3  07-03-1989  07    03  1989  03-07-1989    30's

# %% [markdown]
# # 11. apply() method

# %%
df["name"] = df["name"].apply(lambda x: x.upper())
df
# Out:
#    age   name  id         dob day month  year    mod_date cat_age
# 0   32    RAM   2  01-01-1988  01    01  1988  01-01-1988    30's
# 1   26   SITA   5  02-11-1994  02    11  1994  11-02-1994    20's
# 2   20    SAB   8  04-10-2000  04    10  2000  10-04-2000    20's
# 3   24    RAJ   1  31-13-1996  31    13  1996  13-31-1996    20's
# 4   19  PRIYA  25  02-06-2001  02    06  2001  06-02-2001    20's
# 5   31    TOM   3  07-03-1989  07    03  1989  03-07-1989    30's

# %%
df["odd_even"] = df["id"].apply(lambda x : 0 if x%2==0 else 1)
df
# Out:
#    age   name  id         dob day month  year    mod_date cat_age  odd_even
# 0   32    RAM   2  01-01-1988  01    01  1988  01-01-1988    30's         0
# 1   26   SITA   5  02-11-1994  02    11  1994  11-02-1994    20's         1
# 2   20    SAB   8  04-10-2000  04    10  2000  10-04-2000    20's         0
# 3   24    RAJ   1  31-13-1996  31    13  1996  13-31-1996    20's         1
# 4   19  PRIYA  25  02-06-2001  02    06  2001  06-02-2001    20's         1
# 5   31    TOM   3  07-03-1989  07    03  1989  03-07-1989    30's         1
